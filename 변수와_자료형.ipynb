# %% [markdown]
# <a href="https://colab.research.google.com/github/dj20250218-alt/-/blob/main/%EB%B3%80%EC%88%98%EC%99%80_%EC%9E%90%EB%A3%8C%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #변수와 자료형

# %%
name ="짱구"
height = 170
age= 17
hobby = '요리'
print(name,'키는',height,'나이는',age,'취미는',hobby)
# Out:
# 짱구 키는 170 나이는 17 취미는 요리

# %%
#변수 할당및 등등 외의것
a = 0.09
print(a)
print(type(a))
#변수선언부
age = 16
print(age)
#변수대입부
age = 115
age = 117
print(age)
# Out:
# 0.09
# <class 'float'>
# 16
# 15

# %%
name =input("이름을 입력하세요")
hobby =input("취미를 입력하세요")
age =input("나이를 입력하세요")
height =input("키를 입력하세요")

print(name, hobby, age, height)
# Out:
# 이름을 입력하세요양정우
# 취미를 입력하세요요리
# 나이를 입력하세요18
# 키를 입력하세요180
# 양정우 요리 18 180

# %%
#split()함수활용
#기본값 =공백
#구븐자 지정가능
print(f"{x}")
print(f"{x}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_515/920712232.py in <cell line: 0>()
#       1 #split()함수활용
# ----> 2 x, y = input(), split("=")
#       3 print(f"{x} {y}")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %% [markdown]
# #변수명 작성규칙
# 첫
# 번째 문자는 영문자, 한글 또는 밑줄( _ )
# 로 시작해야 한다.
#
#
# 나머지
# 문자는 영문자, 한글, 밑줄( _ ) , 숫자이어야 한다.
#
#
# if, for와 같은 예약어(특정한 기능으로 사용되도록 미리 약속된 단어)는 사용할 수 없다.
#
#
# 공백과
# 하이픈(-)은 사용할 수 없다.
#
#
# 영문자
# 대소문자를 구별한다.
#
#
# 저장된
# 데이터를 알 수 있도록 의미 있는 이름을 사용하는 것이 좋다.
#
#
# 여러
# 단어로 구성된 변수명을 사용하는 경우에는 각 단어를 밑줄( _ ) 로
# 연결하거나 이어지는 단어를 대문자로 시작하여 가독성을 높이는 것이 좋다(예: sum_result, my_age, sumResult, myAge).

# %%
#변수명 작성규칙
A=530
나이 = 20 #나이를 저장하는변수
print(a)
print(A)
# Out:
# 9
# 5

# %%
# 불 자료형
참 = True
거짓 = False
print(참, type(참))
print(거짓, type(거짓))
print(100 == 20)
print(10 > 5)
# Out:
# True <class 'bool'>
# False <class 'bool'>
# False
# True

# %%
#문자열 자료형

a = '100'
b = 'pyton'

#문자열 연산

print(a+b)#문자열 과 문자열 반복
print(a*10)#특정횟수 만큼 반복
print(a < b)#문자와 길이 비교
print('1' in a)#특정 문자열 포함하는가
print('1' not in a)#특정 문자열을 포함 안하는가
# Out:
# 100pyton
# 100100100100100100100100100100
# True
# True
# False

# %%
#문자열 인덱싱과 슬라이싱
a = "hello"
print(f"첫번쨰 문자 = {a[0]}")
print(f"마지막 문자 = {a[4]}")
print(f"마지막 문자 = {a[-1]}")
# Out:
# 첫번쨰 문자 = h
# 마지막 문자 = o
# 마지막 문자 = o
