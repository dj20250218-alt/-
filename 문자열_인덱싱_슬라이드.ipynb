# %% [markdown]
# <a href="https://colab.research.google.com/github/dj20250218-alt/-/blob/main/%EB%AC%B8%EC%9E%90%EC%97%B4_%EC%9D%B8%EB%8D%B1%EC%8B%B1_%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #문자열 인덱싱 슬라이드

# %%
a="python"
#인덱싱
print(f"{a[0]}")
print(f"{a[5]}")
print(f"{a[-5]}")
#슬라이싱
pinrt(f"{a[1:2]}")
print(f"{a[:6]}")
print(f"{a[0:]}")
print(f"{a[:]}")

# %% [markdown]
# #문자열 관련 함수

# %%
str1='heiio pyton'
print(f"{len(str1)}")

# %%
#주민등록번호받고 알수있게 하는 프로그램(태어난 년도 월 일 )
jumin=input('주민등록번호 입력')
년=jumin[:2]
월=jumin[2:4]
일=jumin[4:]
print(f"연:{년}")
print(f"월:{월}")
print(f"일:{일}")
# Out:
# 주민등록번호 입력20090709
# 연:20
# 월:09
# 일:0709

# %%
#replace =분자
#old = 현재 바꾸고 싶은 문자 문자열에서
#new = 새로 바꿀문자
#count = 변경횟수
original = input("평문입력:")
encryption = original[::-1]
encryption =encryption1.replace('e''3').replace('o''0').replace('l''1')
print(encryption)

# %% [markdown]
# #리스트
# 값을 순차적으로 저장할수 있는 자료형
#
#
# 변수 =[값.값.값]

# %%
a=[]
b=[10,20,40]
c=[1,2,8.9]
d=[2,3,22,2222,56]
print(a,type(a))
print(a,type(b))
print(a,type(c))
# Out:
# [] <class 'list'>
# [] <class 'list'>
# [] <class 'list'>

# %%
#리스트 연산
a=[]
b=[10,20,40]
c=[1,2,8.9]
d=[2,3,22,2222,56]
print(a+c+b)
print(a*8)
print(a<b)
# Out:
# [1, 2, 8.9, 10, 20, 40]
# []
# True

# %%
#리스트 요소 변경
a=[1,2,45,67,66,54]
print('원본:',)
a[2]=100
print('결과:',a)
a[2:]=[10,11]
print('결과:',a)
del a[2]
print('결과:',a)
# Out:
# 원본:
# 결과: [1, 2, 100, 67, 66, 54]
# 결과: [1, 2, 10, 11]
# 결과: [1, 2, 11]

# %%
#range()->range([start],stop,[step])
step=증강값
start =시작값
stop=stop-1까지 생성

list1=list(rangwe(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5563/2210112380.py in <cell line: 0>()
#       1 #range()->range([start],stop,[step])
# ----> 2 step=증강값
#
# NameError: name '증강값' is not defined
