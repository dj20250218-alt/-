# %% [markdown]
# <a href="https://colab.research.google.com/github/dj20250218-alt/-/blob/main/%ED%95%A8%EC%88%98_lipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def 더하기(num1,num2):
    print(f"{num1} + {num2} = {num1+num2}")
더하기(2,5)
# Out:
# 2 + 5 = 7

# %%
def hello()
print("hello world")
hello()

# %%
def 곱하기(a,b):
    c= a*b
    return c
결과=곱하기(3,20)
print(결과)

# %%
def op(num1,num2):
    plus = num1 + num2
    minus = num1 - num2
    multiply = num1 * num2
    divide = num1 / num2
    return plus,minus,multiply,divide

a, b = map(int, input('입력:').split())
p, m, mul, d = op(a, b)
print(f'{a} + {b} = {p}')
print(f'{a} - {b} = {m}')
print(f'{a} * {b} = {mul}')
print(f'{a} / {b} = {d}')
# Out:
# 입력:400 900
# 400 + 900 = 1300
# 400 - 900 = -500
# 400 * 900 = 360000
# 400 / 900 = 0.4444444444444444

# %%
def op(num1,num2):
    plus = num1 + num2
    minus = num1 - num2
    multiply = num1 * num2
    divide = num1 / num2
    return plus,minus,multiply,divide

a, b = map(int, input('입력:').split())
result = op(a, b)
print(result[0])
p, m, mul, d = op(a, b)
print(f'{a} + {b} = {p}')
print(f'{a} - {b} = {m}')
print(f'{a} + {b} = {p}')
print(f'{a} + {b} = {p}')

# %%
def 홀짝(number):
    if number % 2 == 0:
       return '짝수'
num = int(input('정수를 입력하세요:'))
print(홀짝(num))
# Out:
# 정수를 입력하세요:3
# None
